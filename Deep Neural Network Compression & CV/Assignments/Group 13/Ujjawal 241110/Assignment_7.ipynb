# %% [markdown]
# # <font size="7"> **Assignment-6**</font>
# I hope this assignment will give you clarity on how mathematical models like **Multilayer Perceptrons (MLP)** can be made from scratch using **PyTorch** & can be used to solve complex, non-linear geometric problems **without relying on black-box libraries**.
#
# ---
# # ⚫ **Mission Critical: The Exclusion Zone Protocol**
#
# **Date:** Year 2142
# **Location:** Exoplanet *Kepler-186f*   **Clearance:** IITians
#
# ---
#
# ### **⚫ The Story**
# Humanity has colonized the distant exoplanet *Kepler-186f*. While the surface is habitable, the planet's magnetic core is unstable. The **Global Defense Council (GDC)** has identified a dangerous phenomenon known as the **"Radiation Ring."**
#
# Sensors indicate that the safe zones on the planet follow a peculiar geometry:
# * ⚫ **The Core Zone:** Distance $< 2$ km from the colony center (Safe).
# * ⚫ **The Outer Wilds:** Distance $> 4$ km from the colony center (Safe).
# * ⚫ **The Dead Zone:** The region **between 2 km and 4 km** is flooded with lethal gamma radiation.
#
# Your engineering team has deployed **3,000 sensor drones** across the colony to map this danger. Each drone reports its coordinates $(x, y)$ and a binary label:
# * `1`: Radiation Detected (Dead Zone)
# * `0`: Safe Zone
#
#  **⚫ The Problem:** The sensors are cheap and prone to interference. Approximately **5%** of the drones are malfunctioning and reporting the wrong safety status (noise). The GDC mainframe is a legacy system that forbids the use of modern "Neural Libraries" (i.e., you cannot use `torch.nn` or `torch.optim`). You must build a **Multi-Layer Perceptron (MLP) from scratch** to filter out the noise and mathematically define the Exclusion Zone boundaries using **PyTorch**. ( Hint: You know this is a binary classification problem, which Loss function would you use?? )
#
# ---
#
# ### **⚫ Your Objective**
#
# 1.  **Initialize the System:** Use your **Group Number** as the random seed. This ensures your team works on a unique sensor distribution pattern.
# 2.  **Architect the Filter:** Construct a neural network with **3 hidden layers** (16 neurons each) to learn the non-linear "donut" shape of the Dead Zone.
# 3.  **Manual Calibration:** You cannot use auto-optimizers. You must manually calculate the gradients (Backpropagation) and update the system weights using **Gradient Descent**.
# 4.  **Verify Integrity:** Split your sensor data (70% training, 30% validation). Prove that your system doesn't just memorize the malfunctioning sensors (overfitting) but actually learns the geometric shape of the Dead Zone.
#
# ---
#
# ## ⚫ Engineering Constraints (Read Carefully)
#
# **1. Restricted Modules**
# *  **Forbidden:** You are strictly forbidden from importing `torch.nn` (Layers/Loss) or `torch.optim` (Optimizers).
# *  **Allowed:** `import torch`, `import matplotlib.pyplot`, `import pandas`, `import numpy`, using `sklearn`.
#
#
# **2. The Mechanics**
# * **Forward Pass:** Must be implemented using raw matrix multiplication (`torch.matmul`) and bias addition.
# * **Backward Pass:** You **MAY** use `loss.backward()` to compute gradients automatically (Autograd).
# * **Optimization:** You **MUST** implement the weight updates manually (Stochastic Gradient Descent).
#     > `w_new = w_old - learning_rate * w_old.grad`
#
# **3. Loss Function**
# Since `torch.nn` is banned, you must implement **Binary Cross Entropy** manually using basic tensor math.
#
# $$Loss = -\frac{1}{N} \sum_{i=1}^{N} [y_i \cdot \log(\hat{y}_i) + (1-y_i) \cdot \log(1-\hat{y}_i)]$$
#
# * **Note:** Ensure you handle the log of zero (numerical stability) or use `torch.clamp` to avoid `NaN` errors.
#
# **4. Visual Proof:** Your final output must include a Decision Boundary Map showing the "Donut" shape.
#
#
# ---
#
# ### ⚫ **The GDC Dashboard (Required Output)**
#
#
#
# The Global Defense Council requires visual confirmation that your system is stable before we can upload it to the drone fleet. You must generate a **3-Panel Heads-Up Display (HUD)** containing the following telemetry:
#
# **1. System Error Trajectory (Loss Plot)**
# * **Mission:** Plot the **Training Loss** (Blue) vs. **Validation Loss** (Orange) over all epochs.
# * **Why:** We need to confirm that the system is actually learning and not just diverging (exploding gradients).
#
# **2. Integrity Check (Accuracy Plot)**
# * **Mission:** Plot the **Training Accuracy** vs. **Validation Accuracy**.
# * **Why:** If Training Accuracy is high (95%) but Validation Accuracy is low (80%), you have failed to generalize. This is a sign of **Overfitting**—memorizing sensor noise instead of the Radiation Ring.
#
# **3. Geospatial Threat Map (Decision Boundary)**
# * **Mission:** Visualize the **Validation Set** on a 2D map.
# * **Overlay:** Draw the neural network's **Decision Boundary** (the contours where confidence = 0.5).
# * **Why:** The Commander needs to *see* the "Donut" shape. If your boundary looks like a jagged mess, the model is rejected.
#
# ---

# %%
import torch
import numpy as np
# ===========================================================
# PART 1: Data Generation (The Exclusion Zone)
# ===========================================================

# ⚠️ INSTRUCTION: Replace 1 with your actual Group Number
GROUP_NUMBER = 13

# Set seed for reproducibility
torch.manual_seed(GROUP_NUMBER)
np.random.seed(GROUP_NUMBER)

def generate_data(n_samples=3000):
    """
    Generates 3000 sensor readings for the Kepler-186f Exclusion Zone.
    Shape: Concentric circles (Donut).
    Logic:
      - Dead Zone (1): 2km < distance < 4km
      - Safe Zone (0): distance < 2km OR distance > 4km
    """
    # Generate random coordinates between -5 and 5 km
    X = (torch.rand(n_samples, 2) * 10) - 5

    # Calculate distance from center (radius)
    radius = torch.sqrt(X[:, 0]**2 + X[:, 1]**2)

    # Assign Labels: 1 if inside the Dead Zone, 0 otherwise
    y = ((radius > 2) & (radius < 4)).float().view(-1, 1)

    # Add 5% Noise (Malfunctioning Drones)
    n_noise = int(0.05 * n_samples)
    noise_indices = torch.randperm(n_samples)[:n_noise]
    y[noise_indices] = 1 - y[noise_indices] # Flip labels

    return X, y

# Generate the dataset
X_full, y_full = generate_data(3000)

print(f"Data Generated: {X_full.shape} samples.")
print(f"Target Generated: {y_full.shape} labels.")

# %%
# ==============================================================================
# Code from here. Best of luckk :)
# ==============================================================================
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


GROUP_NUMBER = 13
torch.manual_seed(GROUP_NUMBER)
np.random.seed(GROUP_NUMBER)

def generate_data(n_samples=3000):
    X = (torch.rand(n_samples, 2) * 10) - 5
    radius = torch.sqrt(X[:, 0]**2 + X[:, 1]**2)
    y = ((radius > 2) & (radius < 4)).float().view(-1, 1)

    n_noise = int(0.05 * n_samples)
    noise_indices = torch.randperm(n_samples)[:n_noise]
    y[noise_indices] = 1 - y[noise_indices]

    return X, y

X_full, y_full = generate_data(3000)



X_train, X_val, y_train, y_val = train_test_split(
    X_full.numpy(), y_full.numpy(), test_size=0.3, random_state=GROUP_NUMBER
)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val   = torch.tensor(y_val, dtype=torch.float32)


def init_weights(in_dim, out_dim):
    w = torch.randn(in_dim, out_dim) * 0.1
    b = torch.zeros(1, out_dim)
    w.requires_grad_()
    b.requires_grad_()
    return w, b

W1, b1 = init_weights(2, 16)
W2, b2 = init_weights(16, 16)
W3, b3 = init_weights(16, 16)
W4, b4 = init_weights(16, 1)



def relu(x):
    return torch.clamp(x, min=0)

def sigmoid(x):
    return 1 / (1 + torch.exp(-x))

def forward(X):
    z1 = torch.matmul(X, W1) + b1
    a1 = relu(z1)

    z2 = torch.matmul(a1, W2) + b2
    a2 = relu(z2)

    z3 = torch.matmul(a2, W3) + b3
    a3 = relu(z3)

    z4 = torch.matmul(a3, W4) + b4
    y_hat = sigmoid(z4)

    return y_hat


def binary_cross_entropy(y_hat, y):
    eps = 1e-7
    y_hat = torch.clamp(y_hat, eps, 1 - eps)
    loss = -torch.mean(y * torch.log(y_hat) + (1 - y) * torch.log(1 - y_hat))
    return loss

def accuracy(y_hat, y):
    preds = (y_hat >= 0.5).float()
    return (preds == y).float().mean().item()

lr = 0.01
epochs = 10000

train_losses, val_losses = [], []
train_accs, val_accs = [], []

for epoch in range(epochs):
    # -------- Training --------
    y_hat_train = forward(X_train)
    train_loss = binary_cross_entropy(y_hat_train, y_train)
    train_acc = accuracy(y_hat_train, y_train)

    train_loss.backward()

    with torch.no_grad():
        for param in [W1, b1, W2, b2, W3, b3, W4, b4]:
            param -= lr * param.grad
            param.grad.zero_()

    # -------- Validation --------
    with torch.no_grad():
        y_hat_val = forward(X_val)
        val_loss = binary_cross_entropy(y_hat_val, y_val)
        val_acc = accuracy(y_hat_val, y_val)

    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    if epoch % 50 == 0:
        print(f"Epoch {epoch:03d} | "
              f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f} | "
              f"Train Acc: {train_acc:.3f}, Val Acc: {val_acc:.3f}")

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# 1️⃣ Loss Plot
axs[0].plot(train_losses, label="Train Loss")
axs[0].plot(val_losses, label="Validation Loss")
axs[0].set_title("System Error Trajectory")
axs[0].legend()

# 2️⃣ Accuracy Plot
axs[1].plot(train_accs, label="Train Accuracy")
axs[1].plot(val_accs, label="Validation Accuracy")
axs[1].set_title("Integrity Check")
axs[1].legend()

# 3️⃣ Decision Boundary
xx, yy = np.meshgrid(np.linspace(-5, 5, 300), np.linspace(-5, 5, 300))
grid = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32)

with torch.no_grad():
    probs = forward(grid).reshape(xx.shape)

axs[2].contourf(xx, yy, probs, levels=50, cmap="coolwarm", alpha=0.7)
axs[2].contour(xx, yy, probs, levels=[0.5], colors="black")
axs[2].scatter(X_val[:, 0], X_val[:, 1], c=y_val[:, 0], cmap="coolwarm", s=10)
axs[2].set_title("Geospatial Threat Map")

plt.tight_layout()
plt.show()
# Out:
# Epoch 000 | Train Loss: 0.6921, Val Loss: 0.6917 | Train Acc: 0.594, Val Acc: 0.634
# Epoch 050 | Train Loss: 0.6867, Val Loss: 0.6847 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 100 | Train Loss: 0.6827, Val Loss: 0.6792 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 150 | Train Loss: 0.6796, Val Loss: 0.6749 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 200 | Train Loss: 0.6772, Val Loss: 0.6714 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 250 | Train Loss: 0.6754, Val Loss: 0.6687 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 300 | Train Loss: 0.6741, Val Loss: 0.6665 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 350 | Train Loss: 0.6730, Val Loss: 0.6646 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 400 | Train Loss: 0.6722, Val Loss: 0.6632 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 450 | Train Loss: 0.6715, Val Loss: 0.6620 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 500 | Train Loss: 0.6710, Val Loss: 0.6610 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 550 | Train Loss: 0.6706, Val Loss: 0.6601 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 600 | Train Loss: 0.6703, Val Loss: 0.6594 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 650 | Train Loss: 0.6700, Val Loss: 0.6588 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 700 | Train Loss: 0.6698, Val Loss: 0.6583 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 750 | Train Loss: 0.6696, Val Loss: 0.6579 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 800 | Train Loss: 0.6695, Val Loss: 0.6575 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 850 | Train Loss: 0.6694, Val Loss: 0.6572 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 900 | Train Loss: 0.6692, Val Loss: 0.6569 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 950 | Train Loss: 0.6691, Val Loss: 0.6566 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1000 | Train Loss: 0.6690, Val Loss: 0.6564 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1050 | Train Loss: 0.6689, Val Loss: 0.6562 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1100 | Train Loss: 0.6688, Val Loss: 0.6559 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1150 | Train Loss: 0.6687, Val Loss: 0.6557 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1200 | Train Loss: 0.6686, Val Loss: 0.6555 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1250 | Train Loss: 0.6685, Val Loss: 0.6554 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1300 | Train Loss: 0.6684, Val Loss: 0.6552 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1350 | Train Loss: 0.6683, Val Loss: 0.6550 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1400 | Train Loss: 0.6681, Val Loss: 0.6548 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1450 | Train Loss: 0.6680, Val Loss: 0.6546 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1500 | Train Loss: 0.6679, Val Loss: 0.6544 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1550 | Train Loss: 0.6678, Val Loss: 0.6543 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1600 | Train Loss: 0.6676, Val Loss: 0.6541 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1650 | Train Loss: 0.6675, Val Loss: 0.6539 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1700 | Train Loss: 0.6673, Val Loss: 0.6537 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1750 | Train Loss: 0.6672, Val Loss: 0.6535 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1800 | Train Loss: 0.6670, Val Loss: 0.6533 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1850 | Train Loss: 0.6669, Val Loss: 0.6531 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1900 | Train Loss: 0.6667, Val Loss: 0.6528 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 1950 | Train Loss: 0.6665, Val Loss: 0.6526 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2000 | Train Loss: 0.6663, Val Loss: 0.6524 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2050 | Train Loss: 0.6661, Val Loss: 0.6521 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2100 | Train Loss: 0.6659, Val Loss: 0.6519 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2150 | Train Loss: 0.6657, Val Loss: 0.6516 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2200 | Train Loss: 0.6655, Val Loss: 0.6513 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2250 | Train Loss: 0.6653, Val Loss: 0.6510 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2300 | Train Loss: 0.6650, Val Loss: 0.6507 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2350 | Train Loss: 0.6648, Val Loss: 0.6504 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2400 | Train Loss: 0.6645, Val Loss: 0.6501 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2450 | Train Loss: 0.6643, Val Loss: 0.6497 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2500 | Train Loss: 0.6640, Val Loss: 0.6493 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2550 | Train Loss: 0.6637, Val Loss: 0.6490 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2600 | Train Loss: 0.6633, Val Loss: 0.6486 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2650 | Train Loss: 0.6630, Val Loss: 0.6481 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2700 | Train Loss: 0.6627, Val Loss: 0.6477 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2750 | Train Loss: 0.6623, Val Loss: 0.6472 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2800 | Train Loss: 0.6619, Val Loss: 0.6468 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2850 | Train Loss: 0.6615, Val Loss: 0.6463 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2900 | Train Loss: 0.6611, Val Loss: 0.6457 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 2950 | Train Loss: 0.6607, Val Loss: 0.6452 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3000 | Train Loss: 0.6602, Val Loss: 0.6446 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3050 | Train Loss: 0.6597, Val Loss: 0.6440 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3100 | Train Loss: 0.6592, Val Loss: 0.6433 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3150 | Train Loss: 0.6587, Val Loss: 0.6427 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3200 | Train Loss: 0.6582, Val Loss: 0.6420 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3250 | Train Loss: 0.6576, Val Loss: 0.6413 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3300 | Train Loss: 0.6570, Val Loss: 0.6405 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3350 | Train Loss: 0.6564, Val Loss: 0.6397 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3400 | Train Loss: 0.6557, Val Loss: 0.6389 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3450 | Train Loss: 0.6550, Val Loss: 0.6380 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3500 | Train Loss: 0.6543, Val Loss: 0.6372 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3550 | Train Loss: 0.6536, Val Loss: 0.6362 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3600 | Train Loss: 0.6529, Val Loss: 0.6353 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3650 | Train Loss: 0.6521, Val Loss: 0.6343 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3700 | Train Loss: 0.6513, Val Loss: 0.6333 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3750 | Train Loss: 0.6504, Val Loss: 0.6322 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3800 | Train Loss: 0.6496, Val Loss: 0.6312 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3850 | Train Loss: 0.6487, Val Loss: 0.6300 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3900 | Train Loss: 0.6477, Val Loss: 0.6289 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 3950 | Train Loss: 0.6467, Val Loss: 0.6277 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4000 | Train Loss: 0.6457, Val Loss: 0.6265 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4050 | Train Loss: 0.6446, Val Loss: 0.6252 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4100 | Train Loss: 0.6435, Val Loss: 0.6238 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4150 | Train Loss: 0.6423, Val Loss: 0.6225 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4200 | Train Loss: 0.6410, Val Loss: 0.6210 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4250 | Train Loss: 0.6396, Val Loss: 0.6194 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4300 | Train Loss: 0.6381, Val Loss: 0.6178 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4350 | Train Loss: 0.6364, Val Loss: 0.6160 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4400 | Train Loss: 0.6346, Val Loss: 0.6141 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4450 | Train Loss: 0.6325, Val Loss: 0.6119 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4500 | Train Loss: 0.6303, Val Loss: 0.6096 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4550 | Train Loss: 0.6277, Val Loss: 0.6070 | Train Acc: 0.604, Val Acc: 0.634
# Epoch 4600 | Train Loss: 0.6249, Val Loss: 0.6041 | Train Acc: 0.602, Val Acc: 0.633
# Epoch 4650 | Train Loss: 0.6219, Val Loss: 0.6009 | Train Acc: 0.569, Val Acc: 0.599
# Epoch 4700 | Train Loss: 0.6185, Val Loss: 0.5973 | Train Acc: 0.527, Val Acc: 0.561
# Epoch 4750 | Train Loss: 0.6149, Val Loss: 0.5935 | Train Acc: 0.524, Val Acc: 0.554
# Epoch 4800 | Train Loss: 0.6111, Val Loss: 0.5894 | Train Acc: 0.525, Val Acc: 0.558
# Epoch 4850 | Train Loss: 0.6072, Val Loss: 0.5851 | Train Acc: 0.535, Val Acc: 0.570
# Epoch 4900 | Train Loss: 0.6034, Val Loss: 0.5807 | Train Acc: 0.548, Val Acc: 0.582
# Epoch 4950 | Train Loss: 0.5996, Val Loss: 0.5763 | Train Acc: 0.560, Val Acc: 0.590
# Epoch 5000 | Train Loss: 0.5958, Val Loss: 0.5719 | Train Acc: 0.572, Val Acc: 0.594
# Epoch 5050 | Train Loss: 0.5920, Val Loss: 0.5675 | Train Acc: 0.580, Val Acc: 0.607
# Epoch 5100 | Train Loss: 0.5882, Val Loss: 0.5632 | Train Acc: 0.590, Val Acc: 0.616
# Epoch 5150 | Train Loss: 0.5844, Val Loss: 0.5589 | Train Acc: 0.602, Val Acc: 0.626
# Epoch 5200 | Train Loss: 0.5808, Val Loss: 0.5547 | Train Acc: 0.609, Val Acc: 0.630
# Epoch 5250 | Train Loss: 0.5772, Val Loss: 0.5505 | Train Acc: 0.619, Val Acc: 0.637
# Epoch 5300 | Train Loss: 0.5736, Val Loss: 0.5465 | Train Acc: 0.627, Val Acc: 0.657
# Epoch 5350 | Train Loss: 0.5702, Val Loss: 0.5425 | Train Acc: 0.634, Val Acc: 0.658
# Epoch 5400 | Train Loss: 0.5667, Val Loss: 0.5386 | Train Acc: 0.641, Val Acc: 0.669
# Epoch 5450 | Train Loss: 0.5634, Val Loss: 0.5349 | Train Acc: 0.652, Val Acc: 0.676
# Epoch 5500 | Train Loss: 0.5601, Val Loss: 0.5312 | Train Acc: 0.660, Val Acc: 0.682
# Epoch 5550 | Train Loss: 0.5570, Val Loss: 0.5277 | Train Acc: 0.669, Val Acc: 0.691
# Epoch 5600 | Train Loss: 0.5539, Val Loss: 0.5243 | Train Acc: 0.675, Val Acc: 0.694
# Epoch 5650 | Train Loss: 0.5509, Val Loss: 0.5209 | Train Acc: 0.680, Val Acc: 0.698
# Epoch 5700 | Train Loss: 0.5480, Val Loss: 0.5176 | Train Acc: 0.687, Val Acc: 0.703
# Epoch 5750 | Train Loss: 0.5451, Val Loss: 0.5144 | Train Acc: 0.690, Val Acc: 0.709
# Epoch 5800 | Train Loss: 0.5424, Val Loss: 0.5113 | Train Acc: 0.695, Val Acc: 0.713
# Epoch 5850 | Train Loss: 0.5397, Val Loss: 0.5083 | Train Acc: 0.700, Val Acc: 0.720
# Epoch 5900 | Train Loss: 0.5371, Val Loss: 0.5054 | Train Acc: 0.706, Val Acc: 0.724
# Epoch 5950 | Train Loss: 0.5346, Val Loss: 0.5025 | Train Acc: 0.710, Val Acc: 0.730
# Epoch 6000 | Train Loss: 0.5321, Val Loss: 0.4997 | Train Acc: 0.716, Val Acc: 0.733
# Epoch 6050 | Train Loss: 0.5297, Val Loss: 0.4970 | Train Acc: 0.720, Val Acc: 0.738
# Epoch 6100 | Train Loss: 0.5273, Val Loss: 0.4943 | Train Acc: 0.725, Val Acc: 0.739
# Epoch 6150 | Train Loss: 0.5249, Val Loss: 0.4917 | Train Acc: 0.727, Val Acc: 0.741
# Epoch 6200 | Train Loss: 0.5226, Val Loss: 0.4891 | Train Acc: 0.732, Val Acc: 0.743
# Epoch 6250 | Train Loss: 0.5203, Val Loss: 0.4865 | Train Acc: 0.735, Val Acc: 0.748
# Epoch 6300 | Train Loss: 0.5181, Val Loss: 0.4839 | Train Acc: 0.740, Val Acc: 0.753
# Epoch 6350 | Train Loss: 0.5158, Val Loss: 0.4813 | Train Acc: 0.743, Val Acc: 0.758
# Epoch 6400 | Train Loss: 0.5136, Val Loss: 0.4788 | Train Acc: 0.744, Val Acc: 0.760
# Epoch 6450 | Train Loss: 0.5115, Val Loss: 0.4764 | Train Acc: 0.747, Val Acc: 0.762
# Epoch 6500 | Train Loss: 0.5094, Val Loss: 0.4740 | Train Acc: 0.749, Val Acc: 0.764
# Epoch 6550 | Train Loss: 0.5075, Val Loss: 0.4718 | Train Acc: 0.752, Val Acc: 0.767
# Epoch 6600 | Train Loss: 0.5057, Val Loss: 0.4696 | Train Acc: 0.755, Val Acc: 0.768
# Epoch 6650 | Train Loss: 0.5039, Val Loss: 0.4674 | Train Acc: 0.755, Val Acc: 0.770
# Epoch 6700 | Train Loss: 0.5022, Val Loss: 0.4654 | Train Acc: 0.758, Val Acc: 0.776
# Epoch 6750 | Train Loss: 0.5006, Val Loss: 0.4633 | Train Acc: 0.759, Val Acc: 0.776
# Epoch 6800 | Train Loss: 0.4990, Val Loss: 0.4614 | Train Acc: 0.763, Val Acc: 0.776
# Epoch 6850 | Train Loss: 0.4974, Val Loss: 0.4595 | Train Acc: 0.764, Val Acc: 0.776
# Epoch 6900 | Train Loss: 0.4958, Val Loss: 0.4575 | Train Acc: 0.767, Val Acc: 0.777
# Epoch 6950 | Train Loss: 0.4944, Val Loss: 0.4557 | Train Acc: 0.769, Val Acc: 0.778
# Epoch 7000 | Train Loss: 0.4929, Val Loss: 0.4539 | Train Acc: 0.772, Val Acc: 0.782
# Epoch 7050 | Train Loss: 0.4915, Val Loss: 0.4522 | Train Acc: 0.775, Val Acc: 0.783
# Epoch 7100 | Train Loss: 0.4903, Val Loss: 0.4506 | Train Acc: 0.776, Val Acc: 0.782
# Epoch 7150 | Train Loss: 0.4890, Val Loss: 0.4491 | Train Acc: 0.777, Val Acc: 0.786
# Epoch 7200 | Train Loss: 0.4879, Val Loss: 0.4478 | Train Acc: 0.778, Val Acc: 0.789
# Epoch 7250 | Train Loss: 0.4868, Val Loss: 0.4464 | Train Acc: 0.780, Val Acc: 0.793
# Epoch 7300 | Train Loss: 0.4857, Val Loss: 0.4451 | Train Acc: 0.781, Val Acc: 0.794
# Epoch 7350 | Train Loss: 0.4847, Val Loss: 0.4439 | Train Acc: 0.782, Val Acc: 0.796
# Epoch 7400 | Train Loss: 0.4837, Val Loss: 0.4427 | Train Acc: 0.783, Val Acc: 0.798
# Epoch 7450 | Train Loss: 0.4828, Val Loss: 0.4415 | Train Acc: 0.784, Val Acc: 0.799
# Epoch 7500 | Train Loss: 0.4819, Val Loss: 0.4405 | Train Acc: 0.784, Val Acc: 0.800
# Epoch 7550 | Train Loss: 0.4811, Val Loss: 0.4395 | Train Acc: 0.786, Val Acc: 0.799
# Epoch 7600 | Train Loss: 0.4803, Val Loss: 0.4385 | Train Acc: 0.787, Val Acc: 0.799
# Epoch 7650 | Train Loss: 0.4795, Val Loss: 0.4376 | Train Acc: 0.788, Val Acc: 0.799
# Epoch 7700 | Train Loss: 0.4788, Val Loss: 0.4367 | Train Acc: 0.789, Val Acc: 0.799
# Epoch 7750 | Train Loss: 0.4781, Val Loss: 0.4358 | Train Acc: 0.789, Val Acc: 0.799
# Epoch 7800 | Train Loss: 0.4774, Val Loss: 0.4349 | Train Acc: 0.790, Val Acc: 0.802
# Epoch 7850 | Train Loss: 0.4767, Val Loss: 0.4341 | Train Acc: 0.791, Val Acc: 0.802
# Epoch 7900 | Train Loss: 0.4760, Val Loss: 0.4332 | Train Acc: 0.791, Val Acc: 0.802
# Epoch 7950 | Train Loss: 0.4753, Val Loss: 0.4325 | Train Acc: 0.792, Val Acc: 0.803
# Epoch 8000 | Train Loss: 0.4747, Val Loss: 0.4317 | Train Acc: 0.794, Val Acc: 0.802
# Epoch 8050 | Train Loss: 0.4741, Val Loss: 0.4310 | Train Acc: 0.794, Val Acc: 0.803
# Epoch 8100 | Train Loss: 0.4734, Val Loss: 0.4304 | Train Acc: 0.794, Val Acc: 0.804
# Epoch 8150 | Train Loss: 0.4728, Val Loss: 0.4298 | Train Acc: 0.795, Val Acc: 0.807
# Epoch 8200 | Train Loss: 0.4722, Val Loss: 0.4292 | Train Acc: 0.795, Val Acc: 0.807
# Epoch 8250 | Train Loss: 0.4716, Val Loss: 0.4287 | Train Acc: 0.796, Val Acc: 0.807
# Epoch 8300 | Train Loss: 0.4710, Val Loss: 0.4281 | Train Acc: 0.796, Val Acc: 0.806
# Epoch 8350 | Train Loss: 0.4703, Val Loss: 0.4275 | Train Acc: 0.797, Val Acc: 0.806
# Epoch 8400 | Train Loss: 0.4696, Val Loss: 0.4270 | Train Acc: 0.797, Val Acc: 0.809
# Epoch 8450 | Train Loss: 0.4690, Val Loss: 0.4265 | Train Acc: 0.797, Val Acc: 0.810
# Epoch 8500 | Train Loss: 0.4685, Val Loss: 0.4260 | Train Acc: 0.796, Val Acc: 0.810
# Epoch 8550 | Train Loss: 0.4680, Val Loss: 0.4256 | Train Acc: 0.796, Val Acc: 0.810
# Epoch 8600 | Train Loss: 0.4676, Val Loss: 0.4252 | Train Acc: 0.796, Val Acc: 0.810
# Epoch 8650 | Train Loss: 0.4672, Val Loss: 0.4247 | Train Acc: 0.796, Val Acc: 0.810
# Epoch 8700 | Train Loss: 0.4667, Val Loss: 0.4243 | Train Acc: 0.797, Val Acc: 0.809
# Epoch 8750 | Train Loss: 0.4663, Val Loss: 0.4240 | Train Acc: 0.800, Val Acc: 0.809
# Epoch 8800 | Train Loss: 0.4659, Val Loss: 0.4236 | Train Acc: 0.801, Val Acc: 0.810
# Epoch 8850 | Train Loss: 0.4655, Val Loss: 0.4232 | Train Acc: 0.803, Val Acc: 0.810
# Epoch 8900 | Train Loss: 0.4652, Val Loss: 0.4228 | Train Acc: 0.803, Val Acc: 0.811
# Epoch 8950 | Train Loss: 0.4649, Val Loss: 0.4225 | Train Acc: 0.804, Val Acc: 0.811
# Epoch 9000 | Train Loss: 0.4646, Val Loss: 0.4222 | Train Acc: 0.804, Val Acc: 0.813
# Epoch 9050 | Train Loss: 0.4642, Val Loss: 0.4218 | Train Acc: 0.804, Val Acc: 0.813
# Epoch 9100 | Train Loss: 0.4639, Val Loss: 0.4215 | Train Acc: 0.804, Val Acc: 0.813
# Epoch 9150 | Train Loss: 0.4637, Val Loss: 0.4212 | Train Acc: 0.805, Val Acc: 0.813
# Epoch 9200 | Train Loss: 0.4634, Val Loss: 0.4209 | Train Acc: 0.806, Val Acc: 0.813
# Epoch 9250 | Train Loss: 0.4631, Val Loss: 0.4206 | Train Acc: 0.807, Val Acc: 0.813
# Epoch 9300 | Train Loss: 0.4628, Val Loss: 0.4203 | Train Acc: 0.808, Val Acc: 0.813
# Epoch 9350 | Train Loss: 0.4626, Val Loss: 0.4200 | Train Acc: 0.808, Val Acc: 0.814
# Epoch 9400 | Train Loss: 0.4623, Val Loss: 0.4197 | Train Acc: 0.809, Val Acc: 0.816
# Epoch 9450 | Train Loss: 0.4620, Val Loss: 0.4193 | Train Acc: 0.809, Val Acc: 0.816
# Epoch 9500 | Train Loss: 0.4618, Val Loss: 0.4191 | Train Acc: 0.809, Val Acc: 0.816
# Epoch 9550 | Train Loss: 0.4615, Val Loss: 0.4188 | Train Acc: 0.810, Val Acc: 0.818
# Epoch 9600 | Train Loss: 0.4613, Val Loss: 0.4185 | Train Acc: 0.810, Val Acc: 0.818
# Epoch 9650 | Train Loss: 0.4610, Val Loss: 0.4182 | Train Acc: 0.810, Val Acc: 0.819
# Epoch 9700 | Train Loss: 0.4608, Val Loss: 0.4179 | Train Acc: 0.810, Val Acc: 0.818
# Epoch 9750 | Train Loss: 0.4605, Val Loss: 0.4177 | Train Acc: 0.810, Val Acc: 0.819
# Epoch 9800 | Train Loss: 0.4603, Val Loss: 0.4174 | Train Acc: 0.812, Val Acc: 0.819
# Epoch 9850 | Train Loss: 0.4600, Val Loss: 0.4171 | Train Acc: 0.813, Val Acc: 0.819
# Epoch 9900 | Train Loss: 0.4598, Val Loss: 0.4168 | Train Acc: 0.813, Val Acc: 0.819
# Epoch 9950 | Train Loss: 0.4595, Val Loss: 0.4166 | Train Acc: 0.813, Val Acc: 0.819
