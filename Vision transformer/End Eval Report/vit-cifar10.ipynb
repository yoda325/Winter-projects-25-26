# %% [markdown]
# **The CIFAR-10 Dataset:**
#
# - Contains 60,000 $32 \times 32$ color images.
#
# - Classes (10): Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
# Out:
# 2026-02-07 05:59:39.670146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770443979.897832      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770443979.959913      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770443980.463209      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770443980.463245      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770443980.463248      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770443980.463250      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
(x_train, y_train), (x_test, y_test) =keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# Data Preprocessing

# %%
# Normalizing Pixel valuse
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
# Defining hyperparameter for the data
BATCH_SIZE =64
image_size =32
#converting tf.data.dataset for efficiency
train_ds = ( tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE) )
val_ds = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)
val_ds = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# I0000 00:00:1770444000.993122      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1770444000.998936      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# Visualization of CIFAR-10 Samples:

# %%
class_names = ["Airplane", "Automobile", "Bird", "Cat", "Deer",
    "Dog", "Frog", "Horse", "Ship", "Truck"]
plt.figure(figsize=(10, 10))
for i in range(25):
  plt.subplot(5, 5, i + 1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_train[i])
  plt.xlabel(class_names[y_train[i][0]])
plt.show()

# %% [markdown]
# Data Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# Visualize Augmentation
# Let's show how a single image changes after augmentation
plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(tf.expand_dims(x_train[0], 0))
    plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_image[0])
    plt.axis("off")
plt.suptitle("Augmented Versions of the First Training Image")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7450864..2.077311].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7283599..2.0333612].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8115045..2.0217125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5280808..2.0563726].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8138269..2.0570285].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5226263..2.0294905].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5977025..2.0543344].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9398793..2.0656314].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.850984..2.0512233].

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 8
mlp_head_units = [2048, 1024]

# %% [markdown]
# Patch Creation Layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# Visualizing Patches
import cv2

sample_image = tf.image.resize(tf.convert_to_tensor([x_train[0]]), [image_size, image_size])
patches = Patches(patch_size)(sample_image)

print(f"Image Size: {image_size}x{image_size}")
print(f"Patch Size: {patch_size}x{patch_size}")
print(f"Patches per Image: {patches.shape[1]}")
print(f"Elements per Patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy())
    plt.axis("off")
plt.show()
# Out:
# Image Size: 72x72
# Patch Size: 6x6
# Patches per Image: 144
# Elements per Patch: 108

# %% [markdown]
# Patch Encoder Layer

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# Assemble the ViT Classifier

# %%
def mlp(x, hidden_units, dropout_rate):
    """Helper function to build a Multi-Layer Perceptron block."""
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

def create_vit_classifier():
    inputs = layers.Input(shape=(32, 32, 3))

    # 1. Augment data
    augmented = data_augmentation(inputs)
    # 2. Create patches
    patches = Patches(patch_size)(augmented)

    # 3. Encode patches
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)
    # 4. Create multiple Transformer blocks
    for _ in range(transformer_layers):
        # Layer Normalization 1
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Multi-Head Attention
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization 2
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP Block
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        encoded_patches = layers.Add()([x3, x2])

    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)

    # 6. MLP Head
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # 7. Classify outputs
    logits = layers.Dense(10)(features)
    
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

vit_classifier = create_vit_classifier()
vit_classifier.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 32, 32, 3) │          7 │ input_layer_1[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patches_1 (Patches) │ (None, None, 108) │          0 │ data_augmentatio… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patch_encoder       │ (None, 144, 64)   │     16,192 │ patches_1[0][0]   │
# │ (PatchEncoder)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 144, 64)   │        128 │ patch_encoder[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ patch_encoder[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 144, 128)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 144, 64)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 144, 64)   │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 144, 128)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 144, 64)   │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 144, 64)   │          0 │ dropout_5[0][0],  │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 144, 128)  │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 144, 64)   │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 144, 64)   │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 144, 128)  │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 144, 64)   │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 144, 64)   │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 144, 128)  │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 144, 64)   │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 144, 64)   │          0 │ dropout_14[0][0], │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 144, 128)  │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 144, 64)   │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 144, 64)   │          0 │ dropout_17[0][0], │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 144, 128)  │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 144, 64)   │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 144, 64)   │          0 │ dropout_20[0][0], │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 144, 128)  │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 144, 64)   │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 144, 64)   │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 9216)      │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 9216)      │          0 │ flatten[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 2048)      │ 18,876,416 │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 2048)      │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1024)      │  2,098,176 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 1024)      │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 10)        │     10,250 │ dropout_26[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,666,769 (82.65 MB)
#  Trainable params: 21,666,762 (82.65 MB)
#  Non-trainable params: 7 (32.00 B)

# %% [markdown]
# Compile the Model

# %%
# Creating AdamW optimizer
optimizer = keras.optimizers.AdamW(
    learning_rate=learning_rate, weight_decay=weight_decay
)
# Compiling the model
vit_classifier.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)
# Out:
# Model compiled successfully.

# %% [markdown]
# Training the Model

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
data_augmentation.layers[0].adapt(x_train)

vit_classifier = create_vit_classifier()
optimizer = keras.optimizers.AdamW(
    learning_rate=learning_rate, weight_decay=weight_decay
)
vit_classifier.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)
checkpoint_filepath = "/tmp/checkpoint.weights.h5"
checkpoint_callback = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)
history = vit_classifier.fit(
    train_ds,
    validation_data=val_ds,
    epochs=num_epochs,
    callbacks=[checkpoint_callback, early_stopping],
)
def plot_history(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title(f"Train vs Validation {item}")
    plt.legend()
    plt.grid(True)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plot_history("loss")
plt.subplot(1, 2, 2)
plot_history("accuracy")
plt.show()
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 121s 122ms/step - accuracy: 0.2641 - loss: 2.4111 - top-5-accuracy: 0.7616 - val_accuracy: 0.4839 - val_loss: 1.4098 - val_top-5-accuracy: 0.9262
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.4355 - loss: 1.5773 - top-5-accuracy: 0.8979 - val_accuracy: 0.5393 - val_loss: 1.2871 - val_top-5-accuracy: 0.9412
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.4957 - loss: 1.4277 - top-5-accuracy: 0.9180 - val_accuracy: 0.5808 - val_loss: 1.1748 - val_top-5-accuracy: 0.9485
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.5336 - loss: 1.3208 - top-5-accuracy: 0.9327 - val_accuracy: 0.6185 - val_loss: 1.0866 - val_top-5-accuracy: 0.9584
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.5715 - loss: 1.2312 - top-5-accuracy: 0.9437 - val_accuracy: 0.6482 - val_loss: 1.0258 - val_top-5-accuracy: 0.9592
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.5959 - loss: 1.1479 - top-5-accuracy: 0.9535 - val_accuracy: 0.6649 - val_loss: 0.9562 - val_top-5-accuracy: 0.9692
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6127 - loss: 1.1002 - top-5-accuracy: 0.9562 - val_accuracy: 0.6773 - val_loss: 0.9217 - val_top-5-accuracy: 0.9738
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6354 - loss: 1.0500 - top-5-accuracy: 0.9598 - val_accuracy: 0.6860 - val_loss: 0.8939 - val_top-5-accuracy: 0.9731
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6464 - loss: 1.0113 - top-5-accuracy: 0.9651 - val_accuracy: 0.6981 - val_loss: 0.8643 - val_top-5-accuracy: 0.9773
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6569 - loss: 0.9773 - top-5-accuracy: 0.9695 - val_accuracy: 0.7008 - val_loss: 0.8522 - val_top-5-accuracy: 0.9774
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6693 - loss: 0.9456 - top-5-accuracy: 0.9692 - val_accuracy: 0.7063 - val_loss: 0.8333 - val_top-5-accuracy: 0.9812
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6851 - loss: 0.9028 - top-5-accuracy: 0.9722 - val_accuracy: 0.7215 - val_loss: 0.7868 - val_top-5-accuracy: 0.9805
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.6976 - loss: 0.8670 - top-5-accuracy: 0.9755 - val_accuracy: 0.7300 - val_loss: 0.7657 - val_top-5-accuracy: 0.9818
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7089 - loss: 0.8412 - top-5-accuracy: 0.9762 - val_accuracy: 0.7468 - val_loss: 0.7245 - val_top-5-accuracy: 0.9843
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7199 - loss: 0.8064 - top-5-accuracy: 0.9801 - val_accuracy: 0.7503 - val_loss: 0.6971 - val_top-5-accuracy: 0.9846
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7304 - loss: 0.7817 - top-5-accuracy: 0.9790 - val_accuracy: 0.7647 - val_loss: 0.6695 - val_top-5-accuracy: 0.9870
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7347 - loss: 0.7594 - top-5-accuracy: 0.9812 - val_accuracy: 0.7628 - val_loss: 0.6765 - val_top-5-accuracy: 0.9858
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7481 - loss: 0.7292 - top-5-accuracy: 0.9814 - val_accuracy: 0.7708 - val_loss: 0.6591 - val_top-5-accuracy: 0.9848
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7529 - loss: 0.7135 - top-5-accuracy: 0.9833 - val_accuracy: 0.7776 - val_loss: 0.6536 - val_top-5-accuracy: 0.9854
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7584 - loss: 0.6973 - top-5-accuracy: 0.9844 - val_accuracy: 0.7808 - val_loss: 0.6302 - val_top-5-accuracy: 0.9863
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7638 - loss: 0.6782 - top-5-accuracy: 0.9849 - val_accuracy: 0.7743 - val_loss: 0.6651 - val_top-5-accuracy: 0.9870
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7672 - loss: 0.6692 - top-5-accuracy: 0.9853 - val_accuracy: 0.7855 - val_loss: 0.6123 - val_top-5-accuracy: 0.9905
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 125ms/step - accuracy: 0.7737 - loss: 0.6494 - top-5-accuracy: 0.9869 - val_accuracy: 0.7923 - val_loss: 0.5932 - val_top-5-accuracy: 0.9882
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7779 - loss: 0.6436 - top-5-accuracy: 0.9866 - val_accuracy: 0.7892 - val_loss: 0.6269 - val_top-5-accuracy: 0.9888
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7826 - loss: 0.6239 - top-5-accuracy: 0.9873 - val_accuracy: 0.7855 - val_loss: 0.6213 - val_top-5-accuracy: 0.9865
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7916 - loss: 0.6103 - top-5-accuracy: 0.9877 - val_accuracy: 0.7814 - val_loss: 0.6467 - val_top-5-accuracy: 0.9863
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.7851 - loss: 0.6150 - top-5-accuracy: 0.9877 - val_accuracy: 0.8009 - val_loss: 0.5898 - val_top-5-accuracy: 0.9898
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.7980 - loss: 0.5894 - top-5-accuracy: 0.9891 - val_accuracy: 0.7979 - val_loss: 0.5965 - val_top-5-accuracy: 0.9885
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8035 - loss: 0.5765 - top-5-accuracy: 0.9895 - val_accuracy: 0.7928 - val_loss: 0.5970 - val_top-5-accuracy: 0.9879
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8023 - loss: 0.5694 - top-5-accuracy: 0.9899 - val_accuracy: 0.7980 - val_loss: 0.5795 - val_top-5-accuracy: 0.9888
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8069 - loss: 0.5548 - top-5-accuracy: 0.9904 - val_accuracy: 0.8005 - val_loss: 0.5836 - val_top-5-accuracy: 0.9877
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8119 - loss: 0.5483 - top-5-accuracy: 0.9910 - val_accuracy: 0.8055 - val_loss: 0.5762 - val_top-5-accuracy: 0.9880
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8085 - loss: 0.5492 - top-5-accuracy: 0.9912 - val_accuracy: 0.8012 - val_loss: 0.5779 - val_top-5-accuracy: 0.9901
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8123 - loss: 0.5407 - top-5-accuracy: 0.9906 - val_accuracy: 0.8072 - val_loss: 0.5792 - val_top-5-accuracy: 0.9903
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8199 - loss: 0.5233 - top-5-accuracy: 0.9912 - val_accuracy: 0.8057 - val_loss: 0.5724 - val_top-5-accuracy: 0.9904
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8207 - loss: 0.5121 - top-5-accuracy: 0.9916 - val_accuracy: 0.8070 - val_loss: 0.5695 - val_top-5-accuracy: 0.9887
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8236 - loss: 0.5135 - top-5-accuracy: 0.9917 - val_accuracy: 0.7988 - val_loss: 0.6109 - val_top-5-accuracy: 0.9875
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8250 - loss: 0.5032 - top-5-accuracy: 0.9920 - val_accuracy: 0.8073 - val_loss: 0.5792 - val_top-5-accuracy: 0.9900
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8278 - loss: 0.4970 - top-5-accuracy: 0.9927 - val_accuracy: 0.8086 - val_loss: 0.5670 - val_top-5-accuracy: 0.9896
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8318 - loss: 0.4905 - top-5-accuracy: 0.9928 - val_accuracy: 0.8118 - val_loss: 0.5543 - val_top-5-accuracy: 0.9911
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8362 - loss: 0.4802 - top-5-accuracy: 0.9929 - val_accuracy: 0.8143 - val_loss: 0.5634 - val_top-5-accuracy: 0.9919
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8340 - loss: 0.4783 - top-5-accuracy: 0.9935 - val_accuracy: 0.8042 - val_loss: 0.5830 - val_top-5-accuracy: 0.9893
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8367 - loss: 0.4690 - top-5-accuracy: 0.9942 - val_accuracy: 0.8135 - val_loss: 0.5690 - val_top-5-accuracy: 0.9884
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8414 - loss: 0.4552 - top-5-accuracy: 0.9941 - val_accuracy: 0.8150 - val_loss: 0.5522 - val_top-5-accuracy: 0.9909
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8445 - loss: 0.4545 - top-5-accuracy: 0.9940 - val_accuracy: 0.8140 - val_loss: 0.5475 - val_top-5-accuracy: 0.9897
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8479 - loss: 0.4372 - top-5-accuracy: 0.9945 - val_accuracy: 0.8246 - val_loss: 0.5319 - val_top-5-accuracy: 0.9907
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8486 - loss: 0.4380 - top-5-accuracy: 0.9940 - val_accuracy: 0.8153 - val_loss: 0.5606 - val_top-5-accuracy: 0.9906
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8511 - loss: 0.4264 - top-5-accuracy: 0.9946 - val_accuracy: 0.8184 - val_loss: 0.5551 - val_top-5-accuracy: 0.9893
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8525 - loss: 0.4307 - top-5-accuracy: 0.9939 - val_accuracy: 0.8154 - val_loss: 0.5631 - val_top-5-accuracy: 0.9919
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8588 - loss: 0.4159 - top-5-accuracy: 0.9940 - val_accuracy: 0.8176 - val_loss: 0.5910 - val_top-5-accuracy: 0.9908
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8569 - loss: 0.4122 - top-5-accuracy: 0.9951 - val_accuracy: 0.8246 - val_loss: 0.5524 - val_top-5-accuracy: 0.9898
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.8548 - loss: 0.4251 - top-5-accuracy: 0.9945 - val_accuracy: 0.8142 - val_loss: 0.5858 - val_top-5-accuracy: 0.9880
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8583 - loss: 0.4152 - top-5-accuracy: 0.9951 - val_accuracy: 0.8143 - val_loss: 0.5545 - val_top-5-accuracy: 0.9888
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.8596 - loss: 0.4075 - top-5-accuracy: 0.9961 - val_accuracy: 0.8177 - val_loss: 0.5642 - val_top-5-accuracy: 0.9903
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.8610 - loss: 0.4036 - top-5-accuracy: 0.9954 - val_accuracy: 0.8230 - val_loss: 0.5556 - val_top-5-accuracy: 0.9909
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.8637 - loss: 0.3997 - top-5-accuracy: 0.9954 - val_accuracy: 0.8255 - val_loss: 0.5431 - val_top-5-accuracy: 0.9903

# %% [markdown]
# Evaluation on Test Set

# %%
vit_classifier.load_weights(checkpoint_filepath)
_, accuracy, top_5_accuracy = vit_classifier.evaluate(x_test, y_test)

print(f"\nTest Accuracy: {round(accuracy * 100, 2)}%")
print(f"Top-5 Test Accuracy: {round(top_5_accuracy * 100, 2)}%")

# Generate Confusion Matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get predictions
y_probs = vit_classifier.predict(x_test)
y_preds = np.argmax(y_probs, axis=1)

# Plot Matrix
conf_matrix = confusion_matrix(y_test, y_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Print Classification Report
print(classification_report(y_test, y_preds, target_names=class_names))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8239 - loss: 0.5497 - top-5-accuracy: 0.9909
#
# Test Accuracy: 82.55%
# Top-5 Test Accuracy: 99.03%
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step
#               precision    recall  f1-score   support
#
#     Airplane       0.81      0.88      0.84      1000
#   Automobile       0.92      0.90      0.91      1000
#         Bird       0.83      0.73      0.78      1000
#          Cat       0.68      0.63      0.66      1000
#         Deer       0.77      0.86      0.81      1000
#          Dog       0.78      0.70      0.73      1000
#         Frog       0.84      0.88      0.86      1000
#        Horse       0.89      0.86      0.88      1000
#         Ship       0.90      0.91      0.91      1000
#        Truck       0.84      0.90      0.87      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.82      0.83      0.82     10000
# weighted avg       0.82      0.83      0.82     10000
