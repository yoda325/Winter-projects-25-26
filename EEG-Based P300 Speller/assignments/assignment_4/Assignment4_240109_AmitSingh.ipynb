# %% [markdown]
# # Assignment: Training EEGNet on P300 EEG Data
#
# In this assignment, you will work with real EEG data from a P300 speller experiment and implement the EEGNet architecture to detect P300 responses. The emphasis of this assignment is on understanding and implementing the EEGNet model rather than extensive signal preprocessing.
#
# **Instructions:**
# - Complete the provided code scaffolding
# - Fill in missing logic where indicated
# - Focus especially on the EEGNet architecture and training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Part 1: Loading and Inspecting the Dataset
#
# In this section, you will load the EEG dataset and inspect its basic structure. The dataset contains continuous EEG recordings along with stimulus and label information.

# %%
import scipy.io as sio
import numpy as np

# Load the dataset
# TODO: Update the path if needed
data = sio.loadmat('/content/drive/MyDrive/EEG dataset/Subject_A_Train.mat')

# Inspect available keys
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Signal', 'TargetChar', 'Flashing', 'StimulusCode', 'StimulusType'])

# %% [markdown]
# ## Part 2: Understanding the Experimental Design
#
# The P300 speller paradigm is based on detecting brain responses to rare target stimuli. In this section, you will identify how stimulus timing and labels are encoded in the data.

# %%
# 1. Continuous EEG signal
eeg_signal = data['Signal']

# 2. Stimulus onset information
flashing = data['Flashing']
stimulus_code = data['StimulusCode']

# 3. Target vs non-target labels
stimulus_type = data['StimulusType']

# Print shapes to verify consistency
print("EEG signal shape:", eeg_signal.shape)
print("Flashing shape:", flashing.shape)
print("Stimulus code shape:", stimulus_code.shape)
print("Stimulus type shape:", stimulus_type.shape)
# Out:
# EEG signal shape: (85, 7794, 64)
# Flashing shape: (85, 7794)
# Stimulus code shape: (85, 7794)
# Stimulus type shape: (85, 7794)

# %% [markdown]
# ## Part 3: EEG Epoch Extraction
#
# EEGNet does not operate on continuous EEG. Instead, the signal must be segmented into short epochs following each stimulus. This step converts raw EEG into trials suitable for supervised learning.

# %%
def extract_epochs(signal, stimulus_onsets, labels, fs, t_start=0.0, t_end=0.8):
    start_sample = int(t_start * fs)
    end_sample = int(t_end * fs)
    epoch_length = end_sample - start_sample

    epochs = []
    y = []

    for idx, onset in enumerate(stimulus_onsets):
        start_idx = onset + start_sample
        end_idx = onset + end_sample

        if start_idx >= 0 and end_idx <= signal.shape[0]:
            epoch = signal[start_idx:end_idx, :].T  # (channels, time)
            epochs.append(epoch)
            y.append(labels[idx])

    epochs = np.array(epochs)
    y = np.array(y)

    return epochs, y

# %% [markdown]
# ## Part 4: Preparing Data for EEGNet
#
# In this section, you will perform minimal preprocessing to make the data compatible with EEGNet. Extensive signal processing is not required.

# %%
def prepare_for_eegnet(epochs):
    # Original shape: (num_trials, channels, time)
    return np.expand_dims(epochs, axis=-1)

# %% [markdown]
# ## Part 5: Implementing EEGNet
#
# This is the core part of the assignment. You will implement the EEGNet architecture as discussed in class. Focus on matching the block structure and understanding the role of each layer.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, DepthwiseConv2D,
                                     SeparableConv2D, BatchNormalization,
                                     AveragePooling2D, Dropout, Flatten, Dense)

def EEGNet(nb_classes, Chans, Samples, F1=8, D=2, F2=16, dropoutRate=0.5):

    # Change input shape to channels_last (NHWC)
    inputs = Input(shape=(Chans, Samples, 1))
    x = Conv2D(F1, (1, 64), padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = DepthwiseConv2D((Chans, 1), use_bias=False, depth_multiplier=D,
                        padding='valid')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('elu')(x)
    x = AveragePooling2D((1, 4))(x)
    x = Dropout(dropoutRate)(x)

    x = SeparableConv2D(F2, (1, 16), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('elu')(x)
    x = AveragePooling2D((1, 8))(x)
    x = Dropout(dropoutRate)(x)

    # Classification
    x = Flatten()(x)
    outputs = Dense(nb_classes, activation='softmax')(x)

    return Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# ## Part 6: Training the Model
#
# In this section, you will train EEGNet to distinguish between P300 and non-P300 EEG epochs.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
import tensorflow as tf


tf.keras.backend.set_image_data_format('channels_last')

fs = 250
eeg_signal_full = eeg_signal
flashing_full = flashing
stimulus_type_full = stimulus_type

eeg_data_single_session = eeg_signal_full[0]
flashing_single_session = flashing_full[0]
stimulus_type_single_session = stimulus_type_full[0]

onset_indices = np.where(np.diff(flashing_single_session) == 1)[0] + 1

labels_at_onsets = stimulus_type_single_session[onset_indices]

t_start = 0.0
t_end = 0.8
epochs_raw, y_labels_extracted = extract_epochs(
    signal=eeg_data_single_session,
    stimulus_onsets=onset_indices,
    labels=labels_at_onsets,
    fs=fs,
    t_start=t_start,
    t_end=t_end
)

X = prepare_for_eegnet(epochs_raw)

nb_trials, Chans, Samples, _ = X.shape

nb_classes = 2

model = EEGNet(nb_classes=nb_classes, Chans=Chans, Samples=Samples)

y_cat = to_categorical(y_labels_extracted, num_classes=nb_classes)

X_train, X_val, y_train, y_val = train_test_split(
    X, y_cat, test_size=0.2, random_state=42, stratify=y_labels_extracted
)

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.6520 - loss: 0.6527 - val_accuracy: 0.5833 - val_loss: 0.7082
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.7301 - loss: 0.5509 - val_accuracy: 0.5833 - val_loss: 0.6710
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - accuracy: 0.7086 - loss: 0.6165 - val_accuracy: 0.7500 - val_loss: 0.6394
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.8018 - loss: 0.4325 - val_accuracy: 0.7778 - val_loss: 0.6152
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.8332 - loss: 0.4559 - val_accuracy: 0.8056 - val_loss: 0.5887
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 441ms/step - accuracy: 0.8577 - loss: 0.4533 - val_accuracy: 0.8333 - val_loss: 0.5706
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.7993 - loss: 0.4600 - val_accuracy: 0.8333 - val_loss: 0.5530
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.8243 - loss: 0.4087 - val_accuracy: 0.8333 - val_loss: 0.5433
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.8210 - loss: 0.4145 - val_accuracy: 0.8333 - val_loss: 0.5380
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - accuracy: 0.8870 - loss: 0.3100 - val_accuracy: 0.8333 - val_loss: 0.5237
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 403ms/step - accuracy: 0.8187 - loss: 0.4056 - val_accuracy: 0.8333 - val_loss: 0.5106
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.8209 - loss: 0.3809 - val_accuracy: 0.8056 - val_loss: 0.5100
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.8027 - loss: 0.4075 - val_accuracy: 0.8333 - val_loss: 0.4967
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.7973 - loss: 0.4056 - val_accuracy: 0.8056 - val_loss: 0.4954
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 311ms/step - accuracy: 0.8780 - loss: 0.3193 - val_accuracy: 0.7778 - val_loss: 0.5170
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 433ms/step - accuracy: 0.8457 - loss: 0.3500 - val_accuracy: 0.7500 - val_loss: 0.5315
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.8976 - loss: 0.3064 - val_accuracy: 0.7778 - val_loss: 0.4990
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8999 - loss: 0.2853 - val_accuracy: 0.8333 - val_loss: 0.4973
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - accuracy: 0.8449 - loss: 0.3219 - val_accuracy: 0.8056 - val_loss: 0.5041
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8736 - loss: 0.2854 - val_accuracy: 0.8056 - val_loss: 0.4794
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 430ms/step - accuracy: 0.8826 - loss: 0.2788 - val_accuracy: 0.8333 - val_loss: 0.4481
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.9062 - loss: 0.2581 - val_accuracy: 0.8333 - val_loss: 0.4626
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - accuracy: 0.8906 - loss: 0.2396 - val_accuracy: 0.8056 - val_loss: 0.4548
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.8838 - loss: 0.2461 - val_accuracy: 0.8611 - val_loss: 0.4630
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 372ms/step - accuracy: 0.9276 - loss: 0.2156 - val_accuracy: 0.8333 - val_loss: 0.4814
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9410 - loss: 0.1804 - val_accuracy: 0.8611 - val_loss: 0.5164
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - accuracy: 0.9116 - loss: 0.2032 - val_accuracy: 0.8611 - val_loss: 0.4853
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.9491 - loss: 0.1516 - val_accuracy: 0.8611 - val_loss: 0.4617
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - accuracy: 0.9382 - loss: 0.1462 - val_accuracy: 0.8056 - val_loss: 0.4747
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 444ms/step - accuracy: 0.9370 - loss: 0.1639 - val_accuracy: 0.8333 - val_loss: 0.4767
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9325 - loss: 0.1875 - val_accuracy: 0.8056 - val_loss: 0.4923
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9642 - loss: 0.1357 - val_accuracy: 0.7500 - val_loss: 0.5100
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - accuracy: 0.9818 - loss: 0.1257 - val_accuracy: 0.7500 - val_loss: 0.5413
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9456 - loss: 0.1366 - val_accuracy: 0.8056 - val_loss: 0.5111
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - accuracy: 0.9330 - loss: 0.1460 - val_accuracy: 0.7778 - val_loss: 0.5099
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - accuracy: 0.9546 - loss: 0.1288 - val_accuracy: 0.7500 - val_loss: 0.5450
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - accuracy: 0.9541 - loss: 0.1109 - val_accuracy: 0.7778 - val_loss: 0.5559
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.9668 - loss: 0.1168 - val_accuracy: 0.7500 - val_loss: 0.5596
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 334ms/step - accuracy: 0.9640 - loss: 0.1120 - val_accuracy: 0.8056 - val_loss: 0.5303
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 0.9784 - loss: 0.1223 - val_accuracy: 0.7222 - val_loss: 0.5525
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.9969 - loss: 0.0719 - val_accuracy: 0.8056 - val_loss: 0.5456
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - accuracy: 0.9742 - loss: 0.0872 - val_accuracy: 0.8333 - val_loss: 0.5522
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - accuracy: 0.9864 - loss: 0.1037 - val_accuracy: 0.8611 - val_loss: 0.5507
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 0.9661 - loss: 0.0789 - val_accuracy: 0.7778 - val_loss: 0.5804
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 433ms/step - accuracy: 0.9685 - loss: 0.0956 - val_accuracy: 0.7778 - val_loss: 0.6104
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - accuracy: 0.9910 - loss: 0.0515 - val_accuracy: 0.7500 - val_loss: 0.5909
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9579 - loss: 0.1048 - val_accuracy: 0.7500 - val_loss: 0.5860
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9765 - loss: 0.0873 - val_accuracy: 0.8333 - val_loss: 0.5632
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.9613 - loss: 0.1112 - val_accuracy: 0.8056 - val_loss: 0.5357
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.9816 - loss: 0.0685 - val_accuracy: 0.8056 - val_loss: 0.5444
